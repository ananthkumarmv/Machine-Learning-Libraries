# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5])
y = x**2 + 3

# %%
x, y
# Out:
# (array([1, 2, 3, 4, 5]), array([ 4,  7, 12, 19, 28], dtype=int32))

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.plot(x,y)

# %%
plt.style.use('seaborn')

# %%
plt.plot(x,y)
plt.title("MY Line Plot")
plt.show()

# %%
plt.plot(x,y,label="Stock Price")
plt.title("MY Line Plot")
plt.legend()
plt.show()

# %%
plt.plot(x,y,label="Stock Price 1")
plt.plot(x,x**2,label="Stock Price 2")
plt.title("MY Line Plot")
plt.legend()
plt.show()

# %%
plt.plot(x,y,label="Stock Price 1")
plt.plot(x,x**2,label="Stock Price 2")
plt.title("MY Line Plot")
plt.xlabel("Timestamp")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.scatter(x,y,label="Stock Price 1")
plt.scatter(x,x**2,label="Stock Price 2")
plt.title("MY Scatter Plot")
plt.xlabel("Timestamp")
plt.ylabel("Price")
plt.legend()
plt.show()

# %%
plt.style.use('dark_background')

# %%
plt.scatter(x,y,label="Stock Price 1")
plt.scatter(x,x**2,label="Stock Price 2")
plt.title("MY Scatter Plot")
plt.xlabel("Timestamp")
plt.ylabel("Price")
plt.legend()
plt.show()
