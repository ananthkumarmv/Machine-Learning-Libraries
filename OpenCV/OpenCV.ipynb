# %% [markdown]
# ## Working with OpenCV & Images

# %%
# !pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Pictures\Saved_Pictures\YT.jpg')

# %%
#(pixels, pixels, 3) 
#3 is layer here(rgb) or 3D
#1199*1199 pixels
#each pixels varies from 0-255

img.shape
# Out:
# (1199, 1919, 3)

# %% [markdown]
# ### The below image is not in RGB format instead which is in the BGR format. The reason is, whenever cv reads an image it reads in BGR format. Means OpenCV considers the first channel as blue, second as green, and third as red.
# ### Means Red as Blue, green as it is and Blue as Red.

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### OpenCV gives Methods to switch between colors.

# %% [markdown]
# #### The below image is in the original color

# %%
rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#gray_image = cv2.cvtCOLOR(img, cv2.COLOR_BGR2GRY)

# %%
plt.imshow(rgb_image)
plt.show()

# %%
plt.imshow(rgb_image)
plt.axis("off")
plt.show()

# %%
plt.style.use('seaborn')

# %%
plt.imshow(rgb_image)
plt.show()

# %%
crop_image = rgb_image[300:850, 750:1250, :]
plt.imshow(crop_image)
plt.title("Cropped Image"+str(resize_image.shape))
plt.show()

# %%
crop_image.shape
# Out:
# (550, 500, 3)

# %%
cv2.resize?

# %% [markdown]
# ### Resizing the Image

# %%
#resize(src, dsize[, dst[, fx[, fy[, interpolation]]]])

# %%
resize_image = cv2.resize(crop_image, (100, 100))

# %%
plt.imshow(resize_image)
plt.title("Resized Image"+str(resize_image.shape))
plt.axis("off")
plt.show()
